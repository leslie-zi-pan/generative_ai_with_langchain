# %% [markdown]
# # Memory

# %%
# setting the environment variables, the keys
import sys
import os

sys.path.insert(0, os.path.abspath(".."))

from config import set_environment

# for the keys - as explained early in chapter 2
set_environment()

# %%
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.language_models import FakeListChatModel
from langchain.callbacks.base import BaseCallbackHandler
from langchain_core.messages import trim_messages, HumanMessage

class PrintOutputCallback(BaseCallbackHandler):
    def on_chat_model_start(self, serialised, messages, **kwargs):
        print(f"Amount of input messages: {len(messages)}")

sessions = {}
handler = PrintOutputCallback()
llm = FakeListChatModel(responses=["ai1", "ai2", "ai3"])

def get_session_history(session_id: str):
    if session_id not in sessions:
        sessions[session_id] = InMemoryChatMessageHistory()

    return sessions[session_id]

trimmer = trim_messages(
    max_tokens=1,
    strategy="last",
    token_counter=len,
    include_system=True,
    start_on="human",
)

raw_chain = trimmer | llm
chain = RunnableWithMessageHistory(raw_chain, get_session_history)

config = {"callbacks": [PrintOutputCallback()], "configurable": {"session_id": "1"}}

_ = chain.invoke(
    [HumanMessage("Hi!")],
    config=config
)
print(f"History length: {len(sessions['1'].messages)}")

_ = chain.invoke(
    [HumanMessage("How are you?")],
    config=config,
)
print(f"History length: {len(sessions['1'].messages)}")
# Out:
# Amount of input messages: 1
# History length: 2
# Amount of input messages: 1
# History length: 4

# %%
sessions["1"].messages
# Out:
# [HumanMessage(content='Hi!', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='ai1', additional_kwargs={}, response_metadata={}, id='run--affd7765-e529-4187-8431-6093cec67c39-0'),
#  HumanMessage(content='How are you?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='ai2', additional_kwargs={}, response_metadata={}, id='run--57afe393-7941-4256-9698-afdbdfeac670-0')]

# %%
# Due to the configs - trimmer tries to preserve in pairs as much as possible. As max_token is 1 we end up trimming and not preserving in this particular case
trimmer.invoke(sessions["1"].messages)
# Out:
# []

# %%
from langchain_core.messages import AIMessage

test_trimmer = trim_messages(
    max_tokens=5, # Restrict to max 4 tokens
    strategy="last", # Preserve by latest messages
    token_counter=len, # Max token counter by message lengths - not characters
    include_system=True,
    start_on="human", # Trimmer must start on human first
)
sessions_test_messages = [
    HumanMessage(content="Hi! 0", additional_kwargs={}, response_metadata={}),
    HumanMessage(content="Hi! 0", additional_kwargs={}, response_metadata={}),
    HumanMessage(
        content="I want to talk to you", additional_kwargs={}, response_metadata={}
    ),
    HumanMessage(content="How are you?", additional_kwargs={}, response_metadata={}),
    AIMessage(
        content="ai22",
        additional_kwargs={},
        response_metadata={},
        id="run--d3de9cc7-050f-42f5-b793-cac75100b065-0",
    ),
    HumanMessage(content="Hi! 1", additional_kwargs={}, response_metadata={}),
    HumanMessage(
        content="I want to talk to you", additional_kwargs={}, response_metadata={}
    ),
    HumanMessage(content="How are you?", additional_kwargs={}, response_metadata={}),
    AIMessage(
        content="ai2",
        additional_kwargs={},
        response_metadata={},
        id="run--d3de9cc7-050f-42f5-b793-cac75100b065-0",
    ),
]

# But here we have max token 4 so we preserve the latest message full human to AI pair (it doesnt need to hit the max token count)
test_trimmer.invoke(sessions_test_messages)
# Out:
# [HumanMessage(content='Hi! 1', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I want to talk to you', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='How are you?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='ai2', additional_kwargs={}, response_metadata={}, id='run--d3de9cc7-050f-42f5-b793-cac75100b065-0')]

# %%
# CONTINUE HERE !!
# Upodate Deprecations
from langgraph.graph import StateGraph
from langgraoh.checkpoint.me
StateGraph

# %%
from langgraph.graph import MessagesState
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import AIMessage
from langgraph.graph import START, END


def test_node(state):
    # ignore the last message since it's an input one
    print(f"History length = {len(state[:-1])}")
    return [AIMessage(content="Hello!")]

builder = MessageGraph() 
builder.add_node("test_node", test_node)
builder.add_edge(START, "test_node")
builder.add_edge("test_node", END)

memory = MemorySaver()
graph = builder.compile(checkpointer=memory)
# Out:
# /var/folders/g9/r5wkd4y16551311v_l_3k9q00000gn/T/ipykernel_38369/2255755615.py:12: LangGraphDeprecatedSinceV10: MessageGraph is deprecated in LangGraph v1.0.0, to be removed in v2.0.0. Please use StateGraph with a `messages` key instead. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   builder = MessageGraph()

# %%
_ = graph.invoke([HumanMessage(content="test")], config={"configurable": {"thread_id": "thread-a"}})
_ = graph.invoke([HumanMessage(content="test")], config={"configurable": {"thread_id": "thread-b"}})
_ = graph.invoke([HumanMessage(content="test")], config={"configurable": {"thread_id": "thread-a"}})
# Out:
# History length = 0
# History length = 0
# History length = 2

# %%
checkpoints = list(memory.list(config={"configurable": {"thread_id": "thread-a"}}))
for check_point in checkpoints:
  print(check_point.config["configurable"]["checkpoint_id"])
# Out:
# 1eff8dbc-fe59-662a-8004-064ebb341150
# 1eff8dbc-fe58-6450-8003-2ee2b7ffac5e
# 1eff8dbc-fe56-68b2-8002-c5562269bb46
# 1eff8dbc-fe48-6f50-8001-710b65f78d1f
# 1eff8dbc-fe3b-6864-8000-d5f811d92d2f
# 1eff8dbc-fe29-6768-bfff-2f0d41677e7c

# %%
checkpoint_id = checkpoints[-1].config["configurable"]["checkpoint_id"]
_ = graph.invoke(
    [HumanMessage(content="test")],
    config={"configurable": {"thread_id": "thread-a", "checkpoint_id": checkpoint_id}})
# Out:
# History length = 0

# %%
checkpoint_id = checkpoints[-3].config["configurable"]["checkpoint_id"]
_ = graph.invoke(
    [HumanMessage(content="test")],
    config={"configurable": {"thread_id": "thread-a", "checkpoint_id": checkpoint_id}})
# Out:
# History length = 2
