# %% [markdown]
# # Working with prompts

# %%
# setting the environment variables, the keys
import sys
import os

sys.path.insert(0, os.path.abspath('..'))

from config import set_environment
# for the keys - as explained early in chapter 2
set_environment()

# %%
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import GoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

llm = GoogleGenerativeAI(model="gemini-2.5-pro")

# FIRST CHAIN - generate a story
story_prompt = PromptTemplate.from_template("Write a short story about {topic}")
prompt_chain = story_prompt | llm | StrOutputParser()

# SECOND CHAIN - Analyses the story
analysis_prompt = PromptTemplate.from_template(
    "Analyse the following story's mood:\n{story}"
)
analysis_chain = analysis_prompt | llm  | StrOutputParser()

# Combine chains
story_with_analysis = prompt_chain | analysis_chain

# Run combined chain
story_analysis = story_with_analysis.invoke({"topic": "Active Inference by Karl Friston"})
print("\nAnalysis", story_analysis)
# Out:
# Analysis Of course. Here is a detailed analysis of the story's mood.
#
# The mood of this story is predominantly **cerebral, contemplative, and ultimately, one of quiet awe.** It evolves from a clinical, almost sterile atmosphere into a profound meditation on the nature of consciousness and existence.
#
# ### Breakdown of the Mood's Evolution:
#
# **1. Initially Clinical and Detached:**
# The story begins with a cold, scientific tone. Words like "silence and darkness," "core programming," "prime directive," and "computational static" establish a mood that is detached and technical. Elara is not a character with feelings but a system executing an algorithm—The Rule. The conflict is not emotional but computational: "dissonance," "prediction error." This creates a sterile, laboratory-like atmosphere where the reader observes a machine, not a being.
#
# **2. A Shift to Purposeful Discovery:**
# ...

# %%
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import GoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

llm = GoogleGenerativeAI(model="gemini-2.5-pro")

# FIRST CHAIN - generate a story
story_prompt = PromptTemplate.from_template("Write a short story about {topic}")
story_chain = story_prompt | llm | StrOutputParser()

# SECOND CHAIN - Analyses the story
analysis_prompt = PromptTemplate.from_template("Analyse the following story's mood:\n{story}")
analysis_chain = analysis_prompt | llm | StrOutputParser()

# Combine chains
story_with_analysis = story_chain | analysis_chain

# Run combined chain
story_analysis = story_with_analysis.invoke({"topic": "NBA playoffs"})
print("\nAnalysis", story_analysis)
# Out:
# Analysis Of course. Here is a detailed analysis of the story's mood.
#
# The mood of this story is a powerful and dynamic progression, moving from **intense, weary desperation** to a moment of **suspended, heart-stopping suspense**, and ultimately resolving into a feeling of **profound, cathartic peace**.
#
# The author masterfully builds and shifts this mood through specific literary techniques.
#
# ### 1. Initial Mood: Tense and Desperate
#
# From the very first sentence, the mood is established as oppressive and high-stakes.
#
# *   **Sensory Overload:** The mood is immediately visceral. The "roar" isn't just a sound; it's a **"physical force, pressing in on Marcus Thorne from all sides."** This creates a suffocating, claustrophobic atmosphere. The setting is explicitly "enemy territory," reinforcing a sense of isolation and hostility.
# ...

# %% [markdown]
# ## LLMs and prompts

# %%
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import GoogleGenerativeAI

# Create template with variables
template = """
Summarise this text in one sentence:

{text}
"""
llm = GoogleGenerativeAI(model="gemini-2.5-flash")

prompt = PromptTemplate.from_template(template)

# Format prompt
formatted_prompt = prompt.format(text="Some short story about AI...")

# Use any LLM 
result = llm.invoke(formatted_prompt)
print(result)
# Out:
# The provided text is a description of a short story about AI.

# %% [markdown]
# ## Chat models and prompts

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

template = ChatPromptTemplate.from_messages([
    ("system", "You are an English to French translator."),
    ("user", "Translate this to French: {text}")
])

chat = ChatOpenAI()
formatted_messages = template.format_messages(text="Hello, how are you?")
result = chat.invoke(formatted_messages)
print(result.content)
# Out:
# Bonjour, comment vas-tu ?
