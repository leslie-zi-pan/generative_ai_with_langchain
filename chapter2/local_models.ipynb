# %% [markdown]
# # Local models

# %% [markdown]
# ## Ollama

# %%
# !pip install langchain-ollama
# !ollama pull deepseek-r1:1.5b
# !ollama serve

# %% [markdown]
# **make sure you've 1. installed ollama, downloaded (pulled) the model, and started "ollama serve" as explained in the book!**

# %%
from langchain_ollama import ChatOllama

chat = ChatOllama(
    model="deepseek-r1:1.5b",
    temperature=0,
)

messages = [
    ("system", "You are a helpful assistant."),
    ("human", "What makes LangChain great for working with LLMs?")
]

ai_msg = chat.invoke(messages)
print(ai_msg.content)
# Out:
# <think>
# Okay, so I'm trying to understand why LangChain is considered great for working with Large Language Models (LLMs). From what I know, LangChain is an open-source project that allows developers to build and deploy models using Python. It's built on PyTorch, which is a popular framework for machine learning and deep learning.
#
# I remember that LLMs are these models that can generate text, like ChatGPT or others. They're used in various applications, from chatbots to content generation. So, if LangChain helps with working with these models, maybe it provides tools or frameworks that make it easier to integrate them into applications.
#
# I think about the key features mentioned earlier: model compatibility, deployment, integration, and scalability. Let me break this down. First, model compatibility—maybe LangChain allows different LLMs to work together smoothly without needing extensive setup. That would be useful for developers who want to use multiple models in their projects.
#
# Next, deployment. I know that deploying models can be tricky because they need to run on specific hardware and might require some infrastructure setup. LangChain probably offers tools or platforms that make this process easier, maybe through APIs or cloud services. This would help businesses integrate LLMs into their operations without dealing with technical complexities.
#
# Integration is another point. If developers want to use LLMs in a particular application, they need the right tools and frameworks. LangChain being open-source means it's community-driven, so there might be support for various applications. It could also provide APIs or libraries that other developers can use, making integration easier across different platforms.
#
# Scalability is important too. As more users start using LLMs, the system needs to handle larger amounts of data and traffic without slowing down. LangChain probably offers scalable solutions, maybe through distributed training or efficient resource management, ensuring that models can scale up as needed.
#
# I also think about how LangChain integrates with other tools. If developers are already using PyTorch for their work, LangChain being built on it would make sense. It could provide a more unified ecosystem where different parts of the model development process (like training, inference, deployment) are connected smoothly.
#
# Another aspect is the community and support. Open-source projects like LangChain have active communities that contribute to improvements and bug fixes. This means developers can get help when they encounter issues, which is crucial for maintaining a good quality of work.
#
# I'm also considering how it handles different LLMs. If someone wants to switch between models or use multiple ones in their application, having tools that allow seamless integration would be beneficial. LangChain's flexibility might make this easier than working with each model separately.
#
# Lastly, scalability and performance are key for any production environment. LangChain probably ensures that models can run efficiently on various hardware configurations, which is important for businesses that need to scale their applications without downtime.
#
# Putting it all together, LangChain seems to offer a comprehensive solution for developers looking to work with LLMs by providing tools for model compatibility, easy deployment, seamless integration across applications, scalability, and community support. This makes it a great choice for anyone in the machine learning space who needs robust and flexible solutions.
# </think>
#
# LangChain is an excellent tool for working with Large Language Models (LLMs) due to its comprehensive features that cater to various aspects of model development and deployment. Here's a structured overview of why LangChain stands out:
#
# 1. **Model Compatibility**: LangChain provides a unified ecosystem where different LLMs can coexist without extensive setup, enhancing flexibility and ease of use for developers.
#
# 2. **Ease of Deployment**: It simplifies the process of deploying models by offering tools or platforms that facilitate infrastructure setup, making it accessible to businesses with varying technical needs.
#
# 3. **Integration Across Applications**: LangChain supports seamless integration into existing applications through APIs and libraries, allowing developers to leverage LLMs effectively in diverse contexts.
#
# 4. **Scalability**: The platform is designed for scalability, ensuring models can handle increased data volumes and traffic without performance degradation, crucial for modern applications.
#
# 5. **Community Support**: As an open-source project with active communities, LangChain offers continuous support, providing help and improvements to maintain high-quality work.
#
# 6. **Unified Ecosystem**: Leveraging PyTorch, LangChain provides a cohesive framework that integrates training, inference, and deployment processes, enhancing efficiency and integration across the model development lifecycle.
#
# 7. **Handling Multiple LLMs**: It facilitates seamless integration of multiple models or switching between different ones, making it ideal for applications requiring diverse capabilities.
#
# 8. **Performance and Scalability**: LangChain ensures efficient execution on various hardware configurations, supporting businesses in scaling their applications without downtime.
#
# In summary, LangChain offers a robust, flexible, and scalable solution that empowers developers to effectively utilize LLMs across various applications, supported by active communities for continuous improvement.

# %% [markdown]
# ## Huggingface

# %%
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline

# Create Pipeline with small model:
llm = HuggingFacePipeline.from_model_id(
    model_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
    pipeline_kwargs={
        "max_new_tokens": 512,
        "do_sample": False,
        "repetition_penalty":1.03,
    }
)

chat_model = ChatHuggingFace(llm=llm)

# Usage like any other LangChain LLM
messages = [
    SystemMessage(content="You're a helpful assistant"),
    HumanMessage(content="Explain the concept of machine learning in simple terms"),
]
ai_msg = chat_model.invoke(messages)
print(ai_msg.content)
# Out:
# Device set to use mps:0
