# %%
# setting the environment variables
import sys
import os

sys.path.insert(0, os.path.abspath('..'))

from config import set_environment
set_environment()

# %% [markdown]
# ## Evaluating pass@k performance of code solutions

# %%
# !pip install datasets evaluate --quiet

# %%
from datasets import load_dataset
from evaluate import load

human_eval = load_dataset("openai_humaneval")
code_eval_metric = load("code_eval")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# openai_humaneval/test-00000-of-00001.par(…):   0%|          | 0.00/83.9k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/164 [00:00<?, ? examples/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]

# %%
import os
os.environ["HF_ALLOW_CODE_EVAL"] = "1"

# %%
test_cases = ["assert add(2,3)==5"]
candidates = [["def add(a,b): return a*b", "def add(a,b): return a+b"]]

pass_at_k, results = code_eval_metric.compute(references=test_cases, predictions=candidates, k=[1, 2])

print(pass_at_k)
# Out:
# {'pass@1': 0.5, 'pass@2': 1.0}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

question = """
Given an integer n, return a string array answer (1-indexed) where:

answer[i] == "FizzBuzz" if i is divisible by 3 and 5.
answer[i] == "Fizz" if i is divisible by 3.
answer[i] == "Buzz" if i is divisible by 5.
answer[i] == i (as a string) if none of the above conditions are true.
"""

llm = ChatGoogleGenerativeAI(model="gemini-3-pro-preview")
print(llm.invoke(question).text)
# Out:
# Here is the solution in **Python**, followed by the logic explanation and complexity analysis.
#
# ### Python Code
#
# ```python
# def fizzBuzz(n):
#     answer = []
#
#     # Iterate from 1 to n (inclusive)
#     for i in range(1, n + 1):
#         # Check divisibility by both 3 and 5 first
#         if i % 3 == 0 and i % 5 == 0:
#             answer.append("FizzBuzz")
#         # Check divisibility by 3
#         elif i % 3 == 0:
#             answer.append("Fizz")
#         # Check divisibility by 5
#         elif i % 5 == 0:
#             answer.append("Buzz")
#         # If none of the above, append the number as a string
#         else:
#             answer.append(str(i))
#
#     return answer
# ```
#
# ### Logic Explanation
#
# 1.  **Looping:** We create a loop that runs from integer `1` up to `n`.
# 2.  **Order of Operations:** The order of the `if/elif` statements is critical.
#     *   We must check if a number is divisible by **both** 3 and 5 (which is the same as being divisible by 15) *before* checking them individually.
#     *   If we checked `i % 3 == 0` first, the number 15 would be recorded as "Fizz" instead of "FizzBuzz".
# 3.  **Conditions:**
#     *   If `i % 15 == 0`: Append "FizzBuzz".
#     *   Else if `i % 3 == 0`: Append "Fizz".
#     *   Else if `i % 5 == 0`: Append "Buzz".
#     *   Else: Convert the integer to a string (`str(i)`) and append it.
#
# ### Complexity Analysis
#
# *   **Time Complexity:** $O(n)$
#     *   We iterate through the numbers from 1 to $n$ exactly once.
# *   **Space Complexity:** $O(1)$ (ignoring output storage)
#     *   If we do not count the space required for the output array `answer`, we only use a constant amount of extra space for variables. If we count the output array, it is $O(n)$.
#
# ### Example
# **Input:** `n = 5`
# **Output:** `["1", "2", "Fizz", "4", "Buzz"]`
#
# **Input:** `n = 15`
# **Output:** `[..., "13", "14", "FizzBuzz"]`
